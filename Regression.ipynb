# %%
x<-c(37,45,48,55,58,67,75)
y<-c(112,132,120,154,136,162,164)

# %%
cbind(x,y)
# Out:
#       x   y
# [1,] 37 112
# [2,] 45 132
# [3,] 48 120
# [4,] 55 154
# [5,] 58 136
# [6,] 67 162
# [7,] 75 164

# %%
options(jupyter.plot_mimetypes = 'image/png')
plot(x,y)
result <- lm(y~x)
abline(result)
